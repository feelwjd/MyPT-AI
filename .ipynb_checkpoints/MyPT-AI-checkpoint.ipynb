# %%
import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/H2GPRM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
import requests

# %%
datas = {'userid':'feelwjd'}

# %%
user_res = requests.post("http://3.34.96.177:8000/api/users").text
df_user = pd.read_json(user_res)
df_user
# Out:
#          userid         pw   username  height  weight  sex  \
# 0                     회원가입  undefined       0     0.0    0
# 1          adsf         12       awed       1     2.0    0
# 2   dbehdgns118     123456        유동훈     180    55.0    0
# 3          dfad      adfaf  undefined       0     0.0    0
# 4         dfafa       회원가입  undefined       0     0.0    0
# 5     dhwpals10     qweqwe         오젬     176    70.0    0
# 6   dhwpals1000     qweqwe         오젬     176    70.0    0
# 7   dhwpals1111     qweqwe         오젬     176    70.0    0
# 8    dhwpals123     qweqwe         오젬     176    70.0    0
# 9     dhwpals22     qweqwe         오젬     176    70.0    0
# 10      feelwjd     123456        민정필     172    70.0    0
# 11      hellomy     qweqwe         오젬     176    70.0    0
# 12   hellomy001     qweqwe         오젬     176    70.0    0
# 13   hellomy002     qweqwe         오젬     176    70.0    0
# 14  hellomy0033     qweqwe         오젬     176    70.0    0
# 15     hellomy1     qweqwe         오젬     176    70.0    0
# 16     hh111123     qweqwe         오젬     176    70.0    0
# 17         hhoo     qweqwe         오젬     176    70.0    0
# 18    jasonoh22     123456        오제민     175    70.0    0
# 19      jasonon     qweqwe         오젬     176    70.0    0
# 20      jasonoo     qweqwe         오젬     176    70.0    0
# 21       qqqq0w     qweqwe         오젬     176    70.0    0
# 22       qqqq3w     qweqwe         오젬     176    70.0    0
# 23      qqqqqqw     qweqwe         오젬     176    70.0    0
# 24   testeeeeew     qweqwe         오젬     176    70.0    0
# 25     testgirl     123456   testgirl     155    43.6    1
# 26    testgirl2     123456      girl2     150    50.0    1
# 27    testgirl3     123456      girl3     180    70.0    1
# 28    undefined  undefined  undefined       0     0.0    0
#
#                          image
# 0                    undefined
# 1                       asdfcc
# 2
# 3                    undefined
# 4                    undefined
# 5   public/images/blackcow.png
# 6   public/images/blackcow.png
# 7   public/images/blackcow.png
# 8   public/images/blackcow.png
# 9   public/images/blackcow.png
# 10
# 11  public/images/blackcow.png
# 12  public/images/blackcow.png
# 13  public/images/blackcow.png
# 14  public/images/blackcow.png
# 15  public/images/blackcow.png
# 16  public/images/blackcow.png
# 17  public/images/blackcow.png
# 18
# 19  public/images/blackcow.png
# 20  public/images/blackcow.png
# 21  public/images/blackcow.png
# 22  public/images/blackcow.png
# 23  public/images/blackcow.png
# 24  public/images/blackcow.png
# 25
# 26
# 27
# 28                   undefined

# %%
workout_res = requests.post("http://3.34.96.177:8000/api/workout").text
df_workout = pd.read_json(workout_res)
df_workout
# Out:
#      workoutid part     workoutname  class
# 0            1  유산소             싸이클      1
# 1            2  유산소         엘립티컬 머신      1
# 2            3  유산소         트레드밀 러닝      1
# 3            4  유산소              러닝      0
# 4            5  유산소              버피      0
# ..         ...  ...             ...    ...
# 294        295  전완근      리스트 컬 (덤벨)      0
# 295        296  전완근      리스트 컬 (바벨)      1
# 296        297  전완근          리스트 롤러      1
# 297        298  전완근  리버스 리스트 컬 (바벨)      1
# 298        299  전완근  리버스 리스트 컬 (덤벨)      0
#
# [299 rows x 4 columns]

# %%
routine_res = requests.post("http://3.34.96.177:8000/api/routine").text
df_routine = pd.read_json(routine_res)
df_routine
# Out:
#      routineid        routinename          description
# 0            1  feelwjd's routine          description
# 1            2        dbehdgns118                    2
# 2            3          jasonoh22                    3
# 3            4           testgirl                    4
# 4            5            feelwjd          description
# ..         ...                ...                  ...
# 596        625    feelwjd routine  For MyPT-AI Dataset
# 597        626    feelwjd routine  For MyPT-AI Dataset
# 598        627    feelwjd routine  For MyPT-AI Dataset
# 599        628    feelwjd routine  For MyPT-AI Dataset
# 600        629    feelwjd routine  For MyPT-AI Dataset
#
# [601 rows x 3 columns]

# %%
user_routine_res = requests.post("http://3.34.96.177:8000/api/users-routine",data=datas).txt
df_user_routine = pd.read_json(user_routine_res)
df_user_routine
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12132/657539523.py in <module>
#       1 user_routine_res = requests.post("http://3.34.96.177:8000/api/users-routine",data=datas)
# ----> 2 df_user_routine = pd.read_json(user_routine_res)
#       3 df_user_routine
#
# ~\anaconda3\envs\fitness\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~\anaconda3\envs\fitness\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\fitness\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     605         nrows=nrows,
#     606         storage_options=storage_options,
# --> 607         encoding_errors=encoding_errors,
#     608     )
#     609
#
# ~\anaconda3\envs\fitness\lib\site-packages\pandas\io\json\_json.py in __init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors)
#     673                 raise ValueError("nrows can only be passed if lines=True")
#     674
# --> 675         data = self._get_data_from_filepath(filepath_or_buffer)
#     676         self.data = self._preprocess_data(data)
#     677
#
# ~\anaconda3\envs\fitness\lib\site-packages\pandas\io\json\_json.py in _get_data_from_filepath(self, filepath_or_buffer)
#     716                 compression=self.compression,
#     717                 storage_options=self.storage_options,
# --> 718                 errors=self.encoding_errors,
#     719             )
#     720             filepath_or_buffer = self.handles.handle
#
# ~\anaconda3\envs\fitness\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     611         compression=compression,
#     612         mode=mode,
# --> 613         storage_options=storage_options,
#     614     )
#     615
#
# ~\anaconda3\envs\fitness\lib\site-packages\pandas\io\common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     393     if not is_file_like(filepath_or_buffer):
#     394         msg = f"Invalid file path or buffer object type: {type(filepath_or_buffer)}"
# --> 395         raise ValueError(msg)
#     396
#     397     return IOArgs(
#
# ValueError: Invalid file path or buffer object type: <class 'requests.models.Response'>

# %%
routine_workout_res = requests.post("http://3.34.96.177:8000/api/routine-workout").text
df_routine_workout = pd.read_json(routine_workout_res)
df_routine_workout
# Out:
#       RoutineWorkoutId  routineid  workoutid
# 0                    1          5          1
# 1                    2          5         21
# 2                    3          5         22
# 3                    4          5         24
# 4                    5          5         65
# ...                ...        ...        ...
# 2157              2219        628         24
# 2158              2220        628         65
# 2159              2221        629        274
# 2160              2222        629        278
# 2161              2223        629        272
#
# [2162 rows x 3 columns]

# %%
user_routine_workout_res = requests.post("http://3.34.96.177:8000/api/users-routine-workout").text
df_user_routine_workout = pd.read_json(user_routine_workout_res)
df_user_routine_workout
# Out:
#       UserRoutineWorkoutId  UserRoutineId  workoutid
# 0                        1              5        1.0
# 1                        2              5       21.0
# 2                        3              5       22.0
# 3                        4              5       24.0
# 4                        5              5       65.0
# ...                    ...            ...        ...
# 2140                  2160            626       24.0
# 2141                  2161            626       65.0
# 2142                  2162            627      274.0
# 2143                  2163            627      278.0
# 2144                  2164            627      272.0
#
# [2145 rows x 3 columns]

# %%
df_user_group = df_user_routine_workout.groupby(['UserRoutineId'])
user1 = df_user_group.get_group(1)
user1
# Out:
#      UserRoutineWorkoutId  UserRoutineId  workoutid
# 134                   135              1        1.0
# 135                   136              1        2.0
# 136                   137              1        3.0
# 137                   138              1        4.0
# 138                   139              1        5.0

# %%
user_recommend_dataset = df_user_routine_workout.copy()
user_recommend_dataset
# Out:
#       UserRoutineWorkoutId  UserRoutineId  workoutid
# 0                        1              5        1.0
# 1                        2              5       21.0
# 2                        3              5       22.0
# 3                        4              5       24.0
# 4                        5              5       65.0
# ...                    ...            ...        ...
# 2140                  2160            626       24.0
# 2141                  2161            626       65.0
# 2142                  2162            627      274.0
# 2143                  2163            627      278.0
# 2144                  2164            627      272.0
#
# [2145 rows x 3 columns]

# %%
sns.pairplot(user1[["UserRoutineWorkoutId","workoutid"]], diag_kind="kde")

# %%
df_workout
# Out:
#      workoutid part     workoutname  class
# 0            1  유산소             싸이클      1
# 1            2  유산소         엘립티컬 머신      1
# 2            3  유산소         트레드밀 러닝      1
# 3            4  유산소              러닝      0
# 4            5  유산소              버피      0
# ..         ...  ...             ...    ...
# 294        295  전완근      리스트 컬 (덤벨)      0
# 295        296  전완근      리스트 컬 (바벨)      1
# 296        297  전완근          리스트 롤러      1
# 297        298  전완근  리버스 리스트 컬 (바벨)      1
# 298        299  전완근  리버스 리스트 컬 (덤벨)      0
#
# [299 rows x 4 columns]

# %% [markdown]
# ## 클래스 ( 기구필요여부)에 따른 총 운동량 분석

# %%
workout_class = df_workout.groupby(['class'])
workout_class

# %%
equipment_workout = workout_class.get_group(1)
non_equipment_work = workout_class.get_group(0)

# %%
equipment_workout
# Out:
#      workoutid part     workoutname  class
# 0            1  유산소             싸이클      1
# 1            2  유산소         엘립티컬 머신      1
# 2            3  유산소         트레드밀 러닝      1
# 7            8  유산소           로잉 머신      1
# 8            9  유산소           스텝 머신      1
# ..         ...  ...             ...    ...
# 291        292   이두     리버스 컬 (이지바)      1
# 292        293   이두     프리쳐 컬 (케이블)      1
# 295        296  전완근      리스트 컬 (바벨)      1
# 296        297  전완근          리스트 롤러      1
# 297        298  전완근  리버스 리스트 컬 (바벨)      1
#
# [130 rows x 4 columns]

# %%
e_workout_part = equipment_workout.groupby('part')
e_workout_part.count()
# Out:
#       workoutid  workoutname  class
# part
# 가슴           18           18     18
# 등            26           26     26
# 삼두            9            9      9
# 어깨           19           19     19
# 유산소           7            7      7
# 이두           12           12     12
# 전완근           3            3      3
# 코어            5            5      5
# 하체           31           31     31

# %%
plt.bar(e_workout_part.count().index, e_workout_part.count().workoutid)
# Out:
# <BarContainer object of 9 artists>

# %%
n_workout_part = non_equipment_work.groupby('part')
plt.bar(n_workout_part.count().index, n_workout_part.count().workoutid)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# ## 사용자별 클래스별 운동량 분석

# %%
merge_user = pd.merge(df_user_routine, df_user_routine_workout, how ='outer', on = 'UserRoutineId')
merge_user
# Out:
#       UserRoutineId   userid  routineid               RoutineDate      Time  \
# 0                 1  feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 1                 1  feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 2                 1  feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 3                 1  feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 4                 1  feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# ...             ...      ...        ...                       ...       ...
# 2140            626  feelwjd        628  2021-09-21T00:00:00.000Z  17:14:13
# 2141            626  feelwjd        628  2021-09-21T00:00:00.000Z  17:14:13
# 2142            627  feelwjd        629  2021-09-22T00:00:00.000Z  17:14:13
# 2143            627  feelwjd        629  2021-09-22T00:00:00.000Z  17:14:13
# 2144            627  feelwjd        629  2021-09-22T00:00:00.000Z  17:14:13
#
#       UserRoutineWorkoutId  workoutid
# 0                      135        1.0
# 1                      136        2.0
# 2                      137        3.0
# 3                      138        4.0
# 4                      139        5.0
# ...                    ...        ...
# 2140                  2160       24.0
# 2141                  2161       65.0
# 2142                  2162      274.0
# 2143                  2163      278.0
# 2144                  2164      272.0
#
# [2145 rows x 7 columns]

# %%
merge_user.groupby('userid').get_group("feelwjd")
# Out:
#       UserRoutineId   userid  routineid               RoutineDate      Time  \
# 0                 1  feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 1                 1  feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 2                 1  feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 3                 1  feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 4                 1  feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# ...             ...      ...        ...                       ...       ...
# 2140            626  feelwjd        628  2021-09-21T00:00:00.000Z  17:14:13
# 2141            626  feelwjd        628  2021-09-21T00:00:00.000Z  17:14:13
# 2142            627  feelwjd        629  2021-09-22T00:00:00.000Z  17:14:13
# 2143            627  feelwjd        629  2021-09-22T00:00:00.000Z  17:14:13
# 2144            627  feelwjd        629  2021-09-22T00:00:00.000Z  17:14:13
#
#       UserRoutineWorkoutId  workoutid
# 0                      135        1.0
# 1                      136        2.0
# 2                      137        3.0
# 3                      138        4.0
# 4                      139        5.0
# ...                    ...        ...
# 2140                  2160       24.0
# 2141                  2161       65.0
# 2142                  2162      274.0
# 2143                  2163      278.0
# 2144                  2164      272.0
#
# [2026 rows x 7 columns]

# %%
merge_workout = pd.merge(merge_user.groupby('userid').get_group("feelwjd"), df_workout, how ='inner', on = 'workoutid')
merge_workout
# Out:
#       UserRoutineId   userid  routineid               RoutineDate      Time  \
# 0                 1  feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 1                 5  feelwjd          5  2021-09-24T00:00:00.000Z  23:39:55
# 2                25  feelwjd         25  2021-09-24T00:00:00.000Z  23:39:55
# 3                88  feelwjd         90  2020-04-01T00:00:00.000Z  17:13:55
# 4                91  feelwjd         93  2020-04-04T00:00:00.000Z  17:13:55
# ...             ...      ...        ...                       ...       ...
# 2021            614  feelwjd        616  2021-09-09T00:00:00.000Z  17:14:12
# 2022            484  feelwjd        486  2021-05-02T00:00:00.000Z  17:14:09
# 2023            578  feelwjd        580  2021-08-04T00:00:00.000Z  17:14:12
# 2024            500  feelwjd        502  2021-05-18T00:00:00.000Z  17:14:09
# 2025            506  feelwjd        508  2021-05-24T00:00:00.000Z  17:14:10
#
#       UserRoutineWorkoutId  workoutid part  workoutname  class
# 0                      135        1.0  유산소          싸이클      1
# 1                        1        1.0  유산소          싸이클      1
# 2                      109        1.0  유산소          싸이클      1
# 3                      319        1.0  유산소          싸이클      1
# 4                      333        1.0  유산소          싸이클      1
# ...                    ...        ...  ...          ...    ...
# 2021                  2126      277.0   이두  바이셉 컬 (이지바)      1
# 2022                  1692        8.0  유산소        로잉 머신      1
# 2023                  2018        8.0  유산소        로잉 머신      1
# 2024                  1752      216.0   가슴   벤치 케이블 플라이      1
# 2025                  1775      216.0   가슴   벤치 케이블 플라이      1
#
# [2026 rows x 10 columns]

# %%
merge_workout.sort_values(by='part')
# Out:
#       UserRoutineId   userid  routineid               RoutineDate      Time  \
# 2025            506  feelwjd        508  2021-05-24T00:00:00.000Z  17:14:10
# 1528            231  feelwjd        233  2020-08-22T00:00:00.000Z  17:14:01
# 1529            236  feelwjd        238  2020-08-27T00:00:00.000Z  17:14:01
# 1530            242  feelwjd        244  2020-09-02T00:00:00.000Z  17:14:01
# 1531            258  feelwjd        260  2020-09-18T00:00:00.000Z  17:14:02
# ...             ...      ...        ...                       ...       ...
# 295             135  feelwjd        137  2020-05-18T00:00:00.000Z  17:13:57
# 294             128  feelwjd        130  2020-05-11T00:00:00.000Z  17:13:56
# 293             116  feelwjd        118  2020-04-29T00:00:00.000Z  17:13:56
# 311             249  feelwjd        251  2020-09-09T00:00:00.000Z  17:14:01
# 1368            229  feelwjd        231  2020-08-20T00:00:00.000Z  17:14:01
#
#       UserRoutineWorkoutId  workoutid part        workoutname  class
# 2025                  1775      216.0   가슴         벤치 케이블 플라이      1
# 1528                   866      198.0   가슴   인클라인 벤치 프레스 (덤벨)      0
# 1529                   881      198.0   가슴   인클라인 벤치 프레스 (덤벨)      0
# 1530                   904      198.0   가슴   인클라인 벤치 프레스 (덤벨)      0
# 1531                   956      198.0   가슴   인클라인 벤치 프레스 (덤벨)      0
# ...                    ...        ...  ...                ...    ...
# 295                    503       66.0   하체     시티드 카프레이즈 (머신)      1
# 294                    473       66.0   하체     시티드 카프레이즈 (머신)      1
# 293                    425       66.0   하체     시티드 카프레이즈 (머신)      1
# 311                    930       66.0   하체     시티드 카프레이즈 (머신)      1
# 1368                   859       28.0   하체  스티프 레그 데드리프트 (바벨)      1
#
# [2026 rows x 10 columns]

# %%
feelwjd_part = merge_workout.groupby('part')
plt.bar(feelwjd_part.count().index, feelwjd_part.count().workoutid)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# ## 루틴 분석

# %%
df_user_routine_workout
# Out:
#       UserRoutineWorkoutId  UserRoutineId  workoutid
# 0                        1              5        1.0
# 1                        2              5       21.0
# 2                        3              5       22.0
# 3                        4              5       24.0
# 4                        5              5       65.0
# ...                    ...            ...        ...
# 2140                  2160            626       24.0
# 2141                  2161            626       65.0
# 2142                  2162            627      274.0
# 2143                  2163            627      278.0
# 2144                  2164            627      272.0
#
# [2145 rows x 3 columns]

# %%
routine_list = df_user_routine_workout.groupby('UserRoutineId')
routine_list

# %%
routine_list.get_group(5)
# Out:
#    UserRoutineWorkoutId  UserRoutineId  workoutid
# 0                     1              5        1.0
# 1                     2              5       21.0
# 2                     3              5       22.0
# 3                     4              5       24.0
# 4                     5              5       65.0
# 5                     6              5       66.0

# %%
merge_routine = pd.merge(merge_user, df_workout, how ='inner', on = 'workoutid')
merge_routine
# Out:
#       UserRoutineId       userid  routineid               RoutineDate  \
# 0                 1      feelwjd          1  2021-09-18T00:00:00.000Z
# 1                 5      feelwjd          5  2021-09-24T00:00:00.000Z
# 2                 6  dbehdgns118          6  2021-09-24T00:00:00.000Z
# 3                25      feelwjd         25  2021-09-24T00:00:00.000Z
# 4                88      feelwjd         90  2020-04-01T00:00:00.000Z
# ...             ...          ...        ...                       ...
# 2139            524      feelwjd        526  2021-06-11T00:00:00.000Z
# 2140            530      feelwjd        532  2021-06-17T00:00:00.000Z
# 2141            472      feelwjd        474  2021-04-20T00:00:00.000Z
# 2142            475      feelwjd        477  2021-04-23T00:00:00.000Z
# 2143            614      feelwjd        616  2021-09-09T00:00:00.000Z
#
#           Time  UserRoutineWorkoutId  workoutid part  workoutname  class
# 0     17:29:03                   135        1.0  유산소          싸이클      1
# 1     23:39:55                     1        1.0  유산소          싸이클      1
# 2     23:39:55                    10        1.0  유산소          싸이클      1
# 3     23:39:55                   109        1.0  유산소          싸이클      1
# 4     17:13:55                   319        1.0  유산소          싸이클      1
# ...        ...                   ...        ...  ...          ...    ...
# 2139  17:14:10                  1844      172.0    등     하이 로우 머신      1
# 2140  17:14:10                  1866      172.0    등     하이 로우 머신      1
# 2141  17:14:08                  1642      277.0   이두  바이셉 컬 (이지바)      1
# 2142  17:14:08                  1656      277.0   이두  바이셉 컬 (이지바)      1
# 2143  17:14:12                  2126      277.0   이두  바이셉 컬 (이지바)      1
#
# [2144 rows x 10 columns]

# %%
merge_routine.groupby("routineid").get_group(15)
# Out:
#      UserRoutineId   userid  routineid               RoutineDate      Time  \
# 432             15  feelwjd         15  2021-09-24T00:00:00.000Z  23:39:55
# 680             15  feelwjd         15  2021-09-24T00:00:00.000Z  23:39:55
# 684             15  feelwjd         15  2021-09-24T00:00:00.000Z  23:39:55
# 687             15  feelwjd         15  2021-09-24T00:00:00.000Z  23:39:55
# 694             15  feelwjd         15  2021-09-24T00:00:00.000Z  23:39:55
#
#      UserRoutineWorkoutId  workoutid part  workoutname  class
# 432                    64       31.0   하체      런지 (덤벨)      0
# 680                    60       76.0   하체      와이드 스쿼트      0
# 684                    61       73.0   하체    원레그 레그프레스      1
# 687                    62       75.0   하체  힙 익스텐션 (머신)      1
# 694                    63       35.0   하체     이너 싸이 머신      1

# %%
all_workout = df_workout.groupby('part')
plt.bar(all_workout.count().index, all_workout.count().workoutid)
# Out:
# <BarContainer object of 9 artists>

# %%
all_workout.count()
# Out:
#       workoutid  workoutname  class
# part
# 가슴           35           35     35
# 등            41           41     41
# 삼두           16           16     16
# 어깨           36           36     36
# 유산소          23           23     23
# 이두           23           23     23
# 전완근           5            5      5
# 코어           52           52     52
# 하체           68           68     68
