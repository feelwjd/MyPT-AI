# %%
import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/H2GPRM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
import requests

# %%
user_res = requests.get("http://ec2-3-34-96-177.ap-northeast-2.compute.amazonaws.com:3000/user").text
df_user = pd.read_json(user_res)
df_user
# Out:
#         userid      pw  username  height  weight  sex image
# 0  dbehdgns118  123456       유동훈     180    55.0    0
# 1      feelwjd  123456       민정필     172    70.0    0
# 2    jasonoh22  123456       오제민     175    70.0    0
# 3     testgirl  123456  testgirl     155    43.6    1
# 4    testgirl2  123456     girl2     150    50.0    1

# %%
workout_res = requests.get("http://ec2-3-34-96-177.ap-northeast-2.compute.amazonaws.com:3000/workout").text
df_workout = pd.read_json(workout_res)
df_workout
# Out:
#      workoutid part     workoutname  class
# 0            1  유산소             싸이클      1
# 1            2  유산소         엘립티컬 머신      1
# 2            3  유산소         트레드밀 러닝      1
# 3            4  유산소              러닝      0
# 4            5  유산소              버피      0
# ..         ...  ...             ...    ...
# 294        295  전완근      리스트 컬 (덤벨)      0
# 295        296  전완근      리스트 컬 (바벨)      1
# 296        297  전완근          리스트 롤러      1
# 297        298  전완근  리버스 리스트 컬 (바벨)      1
# 298        299  전완근  리버스 리스트 컬 (덤벨)      0
#
# [299 rows x 4 columns]

# %%
routine_res = requests.get("http://ec2-3-34-96-177.ap-northeast-2.compute.amazonaws.com:3000/routine").text
df_routine = pd.read_json(routine_res)
df_routine
# Out:
#     routineid        routinename  description
# 0           1  feelwjd's routine  description
# 1           2        dbehdgns118            2
# 2           3          jasonoh22            3
# 3           4           testgirl            4
# 4           5            feelwjd  description
# 5           6        dbehdgns118  description
# 6           7           testgirl  description
# 7           8          testgirl2  description
# 8           9          jasonoh22  description
# 9          10            feelwjd  description
# 10         11        dbehdgns118  description
# 11         12           testgirl  description
# 12         13          testgirl2  description
# 13         14          jasonoh22  description
# 14         15            feelwjd  description
# 15         16        dbehdgns118  description
# 16         17           testgirl  description
# 17         18          testgirl2  description
# 18         19          jasonoh22  description
# 19         20            feelwjd  description
# 20         21        dbehdgns118  description
# 21         22           testgirl  description
# 22         23          testgirl2  description
# 23         24          jasonoh22  description
# 24         25            feelwjd  description
# 25         26        dbehdgns118  description
# 26         27           testgirl  description
# 27         28          testgirl2  description
# 28         29          jasonoh22  description

# %%
user_routine_res = requests.get("http://ec2-3-34-96-177.ap-northeast-2.compute.amazonaws.com:3000/user-routine").text
df_user_routine = pd.read_json(user_routine_res)
df_user_routine
# Out:
#     UserRoutineId       userid  routineid               RoutineDate      Time
# 0               1      feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 1               2  dbehdgns118          2  2021-09-21T00:00:00.000Z  21:59:00
# 2               3    jasonoh22          3  2021-09-21T00:00:00.000Z  21:59:00
# 3               4     testgirl          4  2021-09-21T00:00:00.000Z  21:59:00
# 4               5      feelwjd          5  2021-09-24T00:00:00.000Z  23:39:55
# 5               6  dbehdgns118          6  2021-09-24T00:00:00.000Z  23:39:55
# 6               7     testgirl          7  2021-09-24T00:00:00.000Z  23:39:55
# 7               8    testgirl2          8  2021-09-24T00:00:00.000Z  23:39:55
# 8               9    jasonoh22          9  2021-09-24T00:00:00.000Z  23:39:55
# 9              10      feelwjd         10  2021-09-24T00:00:00.000Z  23:39:55
# 10             11  dbehdgns118         11  2021-09-24T00:00:00.000Z  23:39:55
# 11             12     testgirl         12  2021-09-24T00:00:00.000Z  23:39:55
# 12             13    testgirl2         13  2021-09-24T00:00:00.000Z  23:39:55
# 13             14    jasonoh22         14  2021-09-24T00:00:00.000Z  23:39:55
# 14             15      feelwjd         15  2021-09-24T00:00:00.000Z  23:39:55
# 15             16  dbehdgns118         16  2021-09-24T00:00:00.000Z  23:39:55
# 16             17     testgirl         17  2021-09-24T00:00:00.000Z  23:39:55
# 17             18    testgirl2         18  2021-09-24T00:00:00.000Z  23:39:55
# 18             19    jasonoh22         19  2021-09-24T00:00:00.000Z  23:39:55
# 19             20      feelwjd         20  2021-09-24T00:00:00.000Z  23:39:55
# 20             21  dbehdgns118         21  2021-09-24T00:00:00.000Z  23:39:55
# 21             22     testgirl         22  2021-09-24T00:00:00.000Z  23:39:55
# 22             23    testgirl2         23  2021-09-24T00:00:00.000Z  23:39:55
# 23             24    jasonoh22         24  2021-09-24T00:00:00.000Z  23:39:55
# 24             25      feelwjd         25  2021-09-24T00:00:00.000Z  23:39:55
# 25             26  dbehdgns118         26  2021-09-24T00:00:00.000Z  23:39:55
# 26             27     testgirl         27  2021-09-24T00:00:00.000Z  23:39:55
# 27             28    testgirl2         28  2021-09-24T00:00:00.000Z  23:39:55
# 28             29    jasonoh22         29  2021-09-24T00:00:00.000Z  23:39:55

# %%
routine_workout_res = requests.get("http://ec2-3-34-96-177.ap-northeast-2.compute.amazonaws.com:3000/routine-workout").text
df_routine_workout = pd.read_json(routine_workout_res)
df_routine_workout
# Out:
#      RoutineWorkoutId  routineid  workoutid
# 0                   0          4         18
# 1                   1          5          1
# 2                   2          5         21
# 3                   3          5         22
# 4                   4          5         24
# ..                ...        ...        ...
# 147               147          3         13
# 148               148          3         14
# 149               149          4         15
# 150               150          4         16
# 151               151          4         17
#
# [152 rows x 3 columns]

# %%
user_routine_workout_res = requests.get("http://ec2-3-34-96-177.ap-northeast-2.compute.amazonaws.com:3000/user-routine-workout").text
df_user_routine_workout = pd.read_json(user_routine_workout_res)
df_user_routine_workout
# Out:
#      UserRoutineWorkoutId  UserRoutineId  workoutid
# 0                       0              4         18
# 1                       1              5          1
# 2                       2              5         21
# 3                       3              5         22
# 4                       4              5         24
# ..                    ...            ...        ...
# 147                   147              3         13
# 148                   148              3         14
# 149                   149              4         15
# 150                   150              4         16
# 151                   151              4         17
#
# [152 rows x 3 columns]

# %%
df_user_group = df_user_routine_workout.groupby(['UserRoutineId'])
user1 = df_user_group.get_group(1)
user1
# Out:
#      UserRoutineWorkoutId  UserRoutineId  workoutid
# 135                   135              1          1
# 136                   136              1          2
# 137                   137              1          3
# 138                   138              1          4
# 139                   139              1          5

# %%
user_recommend_dataset = df_user_routine_workout.copy()
user_recommend_dataset
# Out:
#      UserRoutineWorkoutId  UserRoutineId  workoutid
# 0                       0              4         18
# 1                       1              5          1
# 2                       2              5         21
# 3                       3              5         22
# 4                       4              5         24
# ..                    ...            ...        ...
# 147                   147              3         13
# 148                   148              3         14
# 149                   149              4         15
# 150                   150              4         16
# 151                   151              4         17
#
# [152 rows x 3 columns]

# %%
sns.pairplot(user1[["UserRoutineWorkoutId","workoutid"]], diag_kind="kde")

# %%
df_workout
# Out:
#      workoutid part     workoutname  class
# 0            1  유산소             싸이클      1
# 1            2  유산소         엘립티컬 머신      1
# 2            3  유산소         트레드밀 러닝      1
# 3            4  유산소              러닝      0
# 4            5  유산소              버피      0
# ..         ...  ...             ...    ...
# 294        295  전완근      리스트 컬 (덤벨)      0
# 295        296  전완근      리스트 컬 (바벨)      1
# 296        297  전완근          리스트 롤러      1
# 297        298  전완근  리버스 리스트 컬 (바벨)      1
# 298        299  전완근  리버스 리스트 컬 (덤벨)      0
#
# [299 rows x 4 columns]

# %% [markdown]
# ## 클래스 ( 기구필요여부)에 따른 총 운동량 분석

# %%
workout_class = df_workout.groupby(['class'])
workout_class

# %%
equipment_workout = workout_class.get_group(1)
non_equipment_work = workout_class.get_group(0)

# %%
equipment_workout
# Out:
#      workoutid part     workoutname  class
# 0            1  유산소             싸이클      1
# 1            2  유산소         엘립티컬 머신      1
# 2            3  유산소         트레드밀 러닝      1
# 7            8  유산소           로잉 머신      1
# 8            9  유산소           스텝 머신      1
# ..         ...  ...             ...    ...
# 291        292   이두     리버스 컬 (이지바)      1
# 292        293   이두     프리쳐 컬 (케이블)      1
# 295        296  전완근      리스트 컬 (바벨)      1
# 296        297  전완근          리스트 롤러      1
# 297        298  전완근  리버스 리스트 컬 (바벨)      1
#
# [130 rows x 4 columns]

# %%
e_workout_part = equipment_workout.groupby('part')
e_workout_part.count()
# Out:
#       workoutid  workoutname  class
# part
# 가슴           18           18     18
# 등            26           26     26
# 삼두            9            9      9
# 어깨           19           19     19
# 유산소           7            7      7
# 이두           12           12     12
# 전완근           3            3      3
# 코어            5            5      5
# 하체           31           31     31

# %%
plt.bar(e_workout_part.count().index, e_workout_part.count().workoutid)
# Out:
# <BarContainer object of 9 artists>

# %%
n_workout_part = non_equipment_work.groupby('part')
plt.bar(n_workout_part.count().index, n_workout_part.count().workoutid)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# ## 사용자별 클래스별 운동량 분석

# %%
merge_user = pd.merge(df_user_routine, df_user_routine_workout, how ='outer', on = 'UserRoutineId')
merge_user
# Out:
#      UserRoutineId     userid  routineid               RoutineDate      Time  \
# 0                1    feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 1                1    feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 2                1    feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 3                1    feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 4                1    feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 29             25  feelwjd         25  2021-09-24T00:00:00.000Z  23:39:55
# 30             25  feelwjd         25  2021-09-24T00:00:00.000Z  23:39:55
# 31             25  feelwjd         25  2021-09-24T00:00:00.000Z  23:39:55
#
#     UserRoutineWorkoutId  workoutid part        workoutname  class
# 0                    135          1  유산소                싸이클      1
# 1                      1          1  유산소                싸이클      1
# 2                    109          1  유산소                싸이클      1
# 3                    136          2  유산소            엘립티컬 머신      1
# 4                    108          2  유산소            엘립티컬 머신      1
# 5                    137          3  유산소            트레드밀 러닝      1
# 6                    107          3  유산소            트레드밀 러닝      1
# 7                    138          4  유산소                 러닝      0
# 8                    139          5  유산소                 버피      0
# 9                      2         21  유산소             슬로우 버피      0
# 10                     3         22  유산소              온몸 찢기      0
# 11                     4         24   하체           스쿼트 (바벨)      1
# 12                     5         65   하체      스탠딩 레그 컬 (머신)      1
# 13                     6         66   하체     시티드 카프레이즈 (머신)      1
# 14                    33        299  전완근     리버스 리스트 컬 (덤벨)      0
# 15                    34        278   이두          해머 컬 (덤벨)      0
# 16                    35        276   이두         바이셉 컬 (덤벨)      0
# 17                    36        263   삼두    트라이셉 익스텐션 (케이블)      1
# 18                    37        222   어깨       레터럴 레이즈 (덤벨)      0
# 19                    38         32   하체         핵 스쿼트 (머신)      1
# 20                    39        123   코어            플랭크 푸쉬업      0
# 21                    40        120   코어            크리스 크로스      0
# 22                    60         76   하체            와이드 스쿼트      0
# 23                    61         73   하체          원레그 레그프레스      1
# 24                    62         75   하체        힙 익스텐션 (머신)      1
# 25                    63         35   하체           이너 싸이 머신      1
# 26                    64         31   하체            런지 (덤벨)      0
# 27                    84         92   코어             레그 레이즈      0
# 28                    85        218   가슴          다이아몬드 푸쉬업      0
# 29                   110         46   하체       불가리안 스플릿 스쿼트      0
# 30                   111         98   코어           디클라인 크런치      0
# 31                   112         78   하체  스티프 레그 데드리프트 (덤벨)      0

# %%
merge_workout.sort_values(by='routineid')
# Out:
#     UserRoutineId   userid  routineid               RoutineDate      Time  \
# 0               1  feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 3               1  feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 5               1  feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 7               1  feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 8               1  feelwjd          1  2021-09-18T00:00:00.000Z  17:29:03
# 1               5  feelwjd          5  2021-09-24T00:00:00.000Z  23:39:55
# 9               5  feelwjd          5  2021-09-24T00:00:00.000Z  23:39:55
# 10              5  feelwjd          5  2021-09-24T00:00:00.000Z  23:39:55
# 11              5  feelwjd          5  2021-09-24T00:00:00.000Z  23:39:55
# 12              5  feelwjd          5  2021-09-24T00:00:00.000Z  23:39:55
# 13              5  feelwjd          5  2021-09-24T00:00:00.000Z  23:39:55
# 21             10  feelwjd         10  2021-09-24T00:00:00.000Z  23:39:55
# 20             10  feelwjd         10  2021-09-24T00:00:00.000Z  23:39:55
# 19             10  feelwjd         10  2021-09-24T00:00:00.000Z  23:39:55
